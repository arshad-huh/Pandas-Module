# %% [markdown]
# <a href="https://colab.research.google.com/github/arshad-huh/Pandas-Module/blob/main/practice2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
"https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %%
data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills', 'Cranes'],
        'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4, 3.5], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2, 2],
        'priority': ['yes', 'yes', 'no', np.nan, 'no', 'no', 'no', 'yes', 'no', 'no','yes']}

# %%
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']

# %% [markdown]
# ###`Q-1:`
# i. Create a DataFrame birds from the above dictionary data which has the index labels.
#
# ii. Display basic information about the dataFrame.
#
# iii. Show Alternate rows of the dataframe.

# %%
data = pd.DataFrame(data)
data
# Out:
#          birds  age  visits priority
# 0       Cranes  3.5       2      yes
# 1       Cranes  4.0       4      yes
# 2      plovers  1.5       3       no
# 3   spoonbills  NaN       4      NaN
# 4   spoonbills  6.0       3       no
# 5       Cranes  3.0       4       no
# 6      plovers  5.5       2       no
# 7       Cranes  NaN       2      yes
# 8   spoonbills  8.0       3       no
# 9   spoonbills  4.0       2       no
# 10      Cranes  3.5       2      yes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   birds     11 non-null     object
#  1   age       9 non-null      float64
#  2   visits    11 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 480.0+ bytes

# %%
alternate_rows = data.iloc[::2]
alternate_rows
# Out:
#          birds  age  visits priority
# 0       Cranes  3.5       2      yes
# 2      plovers  1.5       3       no
# 4   spoonbills  6.0       3       no
# 6      plovers  5.5       2       no
# 8   spoonbills  8.0       3       no
# 10      Cranes  3.5       2      yes

# %% [markdown]
# ###`Q-2:`
# i. Show only rows [1st, 3rd, 7th] from columns ['bird', 'age']
#
# ii. Select rows where the number of visits is less than 4.

# %%
data.loc[[0,2,6],['birds', 'age']]
# Out:
#      birds  age
# 0   Cranes  3.5
# 2  plovers  1.5
# 6  plovers  5.5

# %%
data[data["visits"] < 4]
# Out:
#          birds  age  visits priority
# 0       Cranes  3.5       2      yes
# 2      plovers  1.5       3       no
# 4   spoonbills  6.0       3       no
# 6      plovers  5.5       2       no
# 7       Cranes  NaN       2      yes
# 8   spoonbills  8.0       3       no
# 9   spoonbills  4.0       2       no
# 10      Cranes  3.5       2      yes

# %% [markdown]
# ###`Q-3:`
# i. Select all rows with nan values in age
#
# ii. Fill nan with respective series mode value.

# %%
data[data["age"].isna()]
# Out:
#         birds  age  visits priority
# 3  spoonbills  NaN       4      NaN
# 7      Cranes  NaN       2      yes

# %%
#Do not use this as they have a special property that they are not equal to themselves.
print(np.nan == np.nan)
# Out:
# False

# %%
mode_age = data['age'].mode()[0]
data['age'].fillna(mode_age)
# Out:
# 0     3.5
# 1     4.0
# 2     1.5
# 3     3.5
# 4     6.0
# 5     3.0
# 6     5.5
# 7     3.5
# 8     8.0
# 9     4.0
# 10    3.5
# Name: age, dtype: float64

# %% [markdown]
# ###`Q-4`
# i. Find the total number of visits of the bird Cranes
#
# ii. Find the number of each type of birds in dataframe.
#
# iii. Print no of duplicate rows
#
# iv. Drop Duplicates rows and make this changes permanent. Show dataframe after changes.

# %%
data
# Out:
#          birds  age  visits priority
# 0       Cranes  3.5       2      yes
# 1       Cranes  4.0       4      yes
# 2      plovers  1.5       3       no
# 3   spoonbills  NaN       4      NaN
# 4   spoonbills  6.0       3       no
# 5       Cranes  3.0       4       no
# 6      plovers  5.5       2       no
# 7       Cranes  NaN       2      yes
# 8   spoonbills  8.0       3       no
# 9   spoonbills  4.0       2       no
# 10      Cranes  3.5       2      yes

# %%
# i. Find the total number of visits of the bird Cranes
total_visits_cranes = data[data["birds"] == "Cranes"]["visits"].sum()
total_visits_cranes
# Out:
# 14

# %%
# ii. Find the number of each type of birds in dataframe.
birds_counts = data["birds"].value_counts()
birds_counts
# Out:
# Cranes        5
# spoonbills    4
# plovers       2
# Name: birds, dtype: int64

# %%
# iii. Print no of duplicate rows
duplicate_rows = data[data.duplicated()]
len(duplicate_rows)
# Out:
# 1

# %%
# iv. Drop Duplicates rows and make this changes permanent. Show dataframe after changes.
data.drop_duplicates(inplace=True)
data
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2      yes
# 1      Cranes  4.0       4      yes
# 2     plovers  1.5       3       no
# 3  spoonbills  NaN       4      NaN
# 4  spoonbills  6.0       3       no
# 5      Cranes  3.0       4       no
# 6     plovers  5.5       2       no
# 7      Cranes  NaN       2      yes
# 8  spoonbills  8.0       3       no
# 9  spoonbills  4.0       2       no

# %% [markdown]
# ##Question on IPL Data
#
# IPL Data Link :  https://drive.google.com/file/d/1yKVUuexl6lIKuFQy7uIPgDgXhJ0L4SIg/view?usp=share_link
#
# https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv
#
# Download ipl matches 2008-2022 file.

# %% [markdown]
# ###`Q-5:` In IPL matches dataset some teams name has changed.
# You will have to consider them as same.
# ```
# 'Delhi Capitals' formerly as 'Delhi Daredevils'
# 'Punjab Kings' formerly as 'Kings XI Punjab'
# 'Rising Pune Supergiant' formerly as 'Rising Pune Supergiants'
# ```
# You need to make changes accordingly. Consider current name for each teams.
#
# Be careful Gujrat Titans and Gujrat Lions are different teams.

# %%
ipl = pd.read_csv("/content/IPL_Matches_2008_2022.csv")
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['Team1'].replace({'Delhi Daredevils': 'Delhi Capitals',
                    'Kings XI Punjab': 'Punjab Kings',
                    'Rising Pune Supergiants': 'Rising Pune Supergiant'}, inplace=True)

ipl['Team2'].replace({'Delhi Daredevils': 'Delhi Capitals',
                    'Kings XI Punjab': 'Punjab Kings',
                    'Rising Pune Supergiants': 'Rising Pune Supergiant'}, inplace=True)

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# ###`Q-6` Write a code which can display the bar chart of top 5 teams who have played maximum number of matches in the IPL.
# >  Hint: Be careful the data is divided in 2 different cols(Team 1 and Team 2)

# %%
teams_ipl = pd.concat([ipl['Team1'], ipl['Team2']])
teams_counts = teams_ipl.value_counts().head(5)
teams_counts.plot(kind='bar', color='blue', title='Top 5 Teams with Maximum Matches Played', xlabel='Team', ylabel='Number of Matches')
# Out:
# <Axes: title={'center': 'Top 5 Teams with Maximum Matches Played'}, xlabel='Team', ylabel='Number of Matches'>

# %% [markdown]
# ###`Q-7:` Player who got Most no. of player of the match award playing against Mumbai Indians.
# > Just for this question assume player of the match award is given to players from winning team. Although this is true in most of the cases.

# %%
matches_against_mumbai = ipl[(ipl['Team1'] == 'Mumbai Indians') | (ipl['Team2'] == 'Mumbai Indians')]

player_of_the_match_against_mumbai = matches_against_mumbai['Player_of_Match'].value_counts()

player_of_the_match_against_mumbai
# Out:
# RG Sharma       16
# KA Pollard      14
# JJ Bumrah        8
# SR Tendulkar     8
# AT Rayudu        8
#                 ..
# M Morkel         1
# RV Uthappa       1
# TH David         1
# B Kumar          1
# MV Boucher       1
# Name: Player_of_Match, Length: 101, dtype: int64

# %% [markdown]
# ###`Q-8:` Team1 vs Team2 Dashbord
# Create a function which will take two string(name of two teams) as input. Show win Loss record between them and player getting most player of the match award in matches between these two teams.
# ```
# team1_vs_team2('Kolkata Knight Riders','Chennai Super Kings')
# ```

# %%
def team_vs_team_stats(team1, team2):

    matches_between_teams = ipl[((ipl['Team1'] == team1) & (ipl['Team2'] == team2)) |
                                ((ipl['Team1'] == team2) & (ipl['Team2'] == team1))]

    win_loss_record = matches_between_teams['WinningTeam'].value_counts()

    most_player_of_the_match = matches_between_teams['Player_of_Match'].value_counts().idxmax()

    print(f"Win-Loss Record between {team1} and {team2}:\n{win_loss_record}")
    print(f"\nPlayer with most Player of the Match awards in matches between {team1} and {team2}: {most_player_of_the_match}")


team_vs_team_stats('Mumbai Indians', 'Chennai Super Kings')
# Out:
# Win-Loss Record between Mumbai Indians and Chennai Super Kings:
# Mumbai Indians         20
# Chennai Super Kings    14
# Name: WinningTeam, dtype: int64
#
# Player with most Player of the Match awards in matches between Mumbai Indians and Chennai Super Kings: KA Pollard

# %% [markdown]
# ### `Q-9:` Find out the top 7 cities where the matches of Kolkata Knight Riders are played frequently and plot the result as bar chart.
#
# *`.plot(kind = "bar")` can help you to plot the bar chart. Also you can learn more about this method from [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)*

# %%
kkr_matches = ipl[(ipl['Team1'] == 'Kolkata Knight Riders') | (ipl['Team2'] == 'Kolkata Knight Riders')]

top_cities = kkr_matches['City'].value_counts().head(7)

top_cities.plot(kind='bar', color='purple', title='Top 7 Cities where Kolkata Knight Riders Matches are Played Frequently', xlabel='City', ylabel='Number of Matches')
# Out:
# <Axes: title={'center': 'Top 7 Cities where Kolkata Knight Riders Matches are Played Frequently'}, xlabel='City', ylabel='Number of Matches'>

# %% [markdown]
# ### `Q-10:` Find out the average margin for the team Mumbai Indians for only the session 2011.

# %%
mi_matches_2011 = ipl[((ipl['Team1'] == 'Mumbai Indians') | (ipl['Team2'] == 'Mumbai Indians')) & (ipl['Season'] == 2011)]

mi_wins_2011 = mi_matches_2011[mi_matches_2011['WinningTeam'] == 'Mumbai Indians']

formatted_result = average_margin_2011.fillna(0)
formatted_result = mi_wins_2011['WonBy'].mean()

print(f"Average margin for Mumbai Indians in IPL 2011: {average_margin_2011:.2f} runs")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-b707aaad8c2b> in <cell line: 5>()
#       3 mi_wins_2011 = mi_matches_2011[mi_matches_2011['WinningTeam'] == 'Mumbai Indians']
#       4
# ----> 5 formatted_result = average_margin_2011.fillna(0)
#       6 formatted_result = mi_wins_2011['WonBy'].mean()
#       7
#
# AttributeError: 'float' object has no attribute 'fillna'
